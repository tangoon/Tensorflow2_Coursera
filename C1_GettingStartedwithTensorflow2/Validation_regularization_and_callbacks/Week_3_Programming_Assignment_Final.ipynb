# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Model validation on the Iris dataset

# %% [markdown]
# ### Instructions
#
# In this notebook, you will build, compile and fit a neural network model to the Iris dataset. You will also implement validation, regularisation and callbacks to improve your model.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook
from numpy.random import seed
seed(8)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, model_selection 
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras import regularizers

# %% [markdown]
# #### The Iris dataset
#
# In this assignment, you will use the [Iris dataset](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html). It consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. For a reference, see the following papers:
#
# - R. A. Fisher. "The use of multiple measurements in taxonomic problems". Annals of Eugenics. 7 (2): 179–188, 1936.
#
# Your goal is to construct a neural network that classifies each sample into the correct class, as well as applying validation and regularisation techniques.

# %% [markdown]
# #### Load and preprocess the data
#
# First read in the Iris dataset using `datasets.load_iris()`, and split the dataset into training and test sets.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def read_in_and_split_data(iris_data):
    """
    This function takes the Iris dataset as loaded by sklearn.datasets.load_iris(), and then 
    splits so that the training set includes 90% of the full dataset, with the test set 
    making up the remaining 10%.
    Your function should return a tuple (train_data, test_data, train_targets, test_targets) 
    of appropriately split training and test data and targets.
    
    If you would like to import any further packages to aid you in this task, please do so in the 
    Package Imports cell above.
    """
    data = iris_data["data"]
    targets = iris_data["target"]

    train_data, test_data, train_targets, test_targets = train_test_split(data, targets, test_size=0.1)

    return train_data, test_data, train_targets, test_targets

# %%
# Run your function to generate the test and training data.

iris_data = datasets.load_iris()
train_data, test_data, train_targets, test_targets = read_in_and_split_data(iris_data)

# %% [markdown]
# We will now convert the training and test targets using a one hot encoder.

# %%
# Convert targets to a one-hot encoding

train_targets = tf.keras.utils.to_categorical(np.array(train_targets))
test_targets = tf.keras.utils.to_categorical(np.array(test_targets))

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to set the input size in the first layer.
# * The first layer should be a dense layer with 64 units.
# * The weights of the first layer should be initialised with the He uniform initializer.
# * The biases of the first layer should be all initially equal to one.
# * There should then be a further four dense layers, each with 128 units.
# * This should be followed with four dense layers, each with 64 units.
# * All of these Dense layers should use the ReLU activation function.
# * The output Dense layer should have 3 units and the softmax activation function.
#
# In total, the network should have 10 layers.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    he_initializer = tf.keras.initializers.HeUniform()
    ones_initializer = tf.keras.initializers.Ones()

    model = Sequential([
      Dense(64, activation="relu", input_shape=input_shape, 
            kernel_initializer=he_initializer,
            bias_initializer=ones_initializer),
      Dense(128, activation="relu"),
      Dense(128, activation="relu"),
      Dense(128, activation="relu"),
      Dense(128, activation="relu"),
      Dense(64, activation="relu"),
      Dense(64, activation="relu"),
      Dense(64, activation="relu"),
      Dense(64, activation="relu"),
      Dense(3, activation="softmax")                   
  ]
  )

    return model

# %%
# Run your function to get the model

model = get_model(train_data[0].shape)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 64)                320
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_19 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 79,107
# Trainable params: 79,107
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compile the model
#
# You should now compile the model using the `compile` method. Remember that you need to specify an optimizer, a loss function and a metric to judge the performance of your model.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with learning rate set to 0.0001), 
    the categorical crossentropy loss function and accuracy as the only metric. 
    Your function doesn't need to return anything; the model will be compiled in-place.
    """
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Run your function to compile the model

compile_model(model)

# %% [markdown]
# #### Fit the model to the training data
#
# Now you should train the model on the Iris dataset, using the model's `fit` method.
# * Run the training for a fixed number of epochs, given by the function's `epochs` argument.
# * Return the training history to be used for plotting the learning curves.
# * Set the batch size to 40.
# * Set the validation set to be 15% of the training set.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def train_model(model, train_data, train_targets, epochs):
    """
    This function should train the model for the given number of epochs on the 
    train_data and train_targets. 
    Your function should return the training history, as returned by model.fit.
    """
    history = model.fit(train_data, train_targets, batch_size=40, validation_split=0.15, epochs=epochs)
    return history

# %%
# Run your function to train the model

history = train_model(model, train_data, train_targets, epochs=800)

# %% [markdown]
# #### Plot the learning curves
#
# We will now plot two graphs:
# * Epoch vs accuracy
# * Epoch vs loss

# %%
#Run this cell to plot the epoch vs accuracy graph

try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the epoch vs loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Oh no! We have overfit our dataset. You should now try to now try to mitigate this overfitting.

# %% [markdown]
# #### Reducing overfitting in the model

# %% [markdown]
# You should now define a new regularised model.
# The specs for the regularised model are the same as our original model, with the addition of two dropout layers, weight decay, and a batch normalisation layer.
#
# In particular:
#
# * Add a dropout layer after the 3rd Dense layer
# * Then there should be two more Dense layers with 128 units before a batch normalisation layer
# * Following this, two more Dense layers with 64 units and then another Dropout layer
# * Two more Dense layers with 64 units and then the final 3-way softmax layer
# * Add weight decay (l2 kernel regularisation) in all Dense layers except the final softmax layer

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_regularised_model(input_shape, dropout_rate, weight_decay):
    """
    This function should build a regularised Sequential model according to the above specification. 
    The dropout_rate argument in the function should be used to set the Dropout rate for all Dropout layers.
    L2 kernel regularisation (weight decay) should be added using the weight_decay argument to 
    set the weight decay coefficient in all Dense layers that use L2 regularisation.
    Ensure the weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument input_shape.
    Your function should return the model.
    """
    he_initializer = tf.keras.initializers.HeUniform()  # Note here that the function name is different in TF2.0.0 release
    ones_initializer = tf.keras.initializers.Ones()     # Note here that the function name is different in TF2.0.0 release

    model = Sequential([
      Dense(64, activation="relu", input_shape=input_shape, 
            kernel_initializer=he_initializer,
            bias_initializer=ones_initializer, 
            kernel_regularizer=regularizers.l2(weight_decay)),
      Dense(128, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      Dense(128, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      Dropout(dropout_rate),
      Dense(128, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      Dense(128, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      BatchNormalization(),
      Dense(64, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      Dense(64, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      Dropout(dropout_rate),
      Dense(64, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      Dense(64, activation="relu", kernel_regularizer=regularizers.l2(weight_decay)),
      Dense(3, activation="softmax")                   
  ]
  )
    return model

# %% [markdown]
# #### Instantiate, compile and train the model

# %%
# Instantiate the model, using a dropout rate of 0.3 and weight decay coefficient of 0.001

reg_model = get_regularised_model(train_data[0].shape, 0.3, 0.001)

# %%
# Compile the model

compile_model(reg_model)

# %%
# Train the model

reg_history = train_model(reg_model, train_data, train_targets, epochs=800)
# Out:
# Epoch 1/800
# 3/3 [==============================] - 1s 149ms/step - loss: 2.0351 - accuracy: 0.2860 - val_loss: 1.9594 - val_accuracy: 0.3810
# Epoch 2/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9620 - accuracy: 0.3323 - val_loss: 1.9543 - val_accuracy: 0.3810
# Epoch 3/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.9748 - accuracy: 0.3686 - val_loss: 1.9508 - val_accuracy: 0.3333
# Epoch 4/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9864 - accuracy: 0.3817 - val_loss: 1.9459 - val_accuracy: 0.3333
# Epoch 5/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.9408 - accuracy: 0.4262 - val_loss: 1.9409 - val_accuracy: 0.3333
# Epoch 6/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9569 - accuracy: 0.4043 - val_loss: 1.9369 - val_accuracy: 0.3333
# Epoch 7/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9185 - accuracy: 0.4474 - val_loss: 1.9332 - val_accuracy: 0.3333
# Epoch 8/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.9166 - accuracy: 0.4437 - val_loss: 1.9299 - val_accuracy: 0.3333
# Epoch 9/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.9462 - accuracy: 0.4055 - val_loss: 1.9264 - val_accuracy: 0.3333
# Epoch 10/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.9242 - accuracy: 0.4543 - val_loss: 1.9236 - val_accuracy: 0.3333
# Epoch 11/800
# 3/3 [==============================] - 0s 86ms/step - loss: 1.9227 - accuracy: 0.4555 - val_loss: 1.9208 - val_accuracy: 0.3333
# Epoch 12/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9104 - accuracy: 0.4706 - val_loss: 1.9173 - val_accuracy: 0.3333
# Epoch 13/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.8740 - accuracy: 0.5595 - val_loss: 1.9129 - val_accuracy: 0.3333
# Epoch 14/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.8997 - accuracy: 0.5112 - val_loss: 1.9086 - val_accuracy: 0.3333
# Epoch 15/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.8867 - accuracy: 0.4850 - val_loss: 1.9042 - val_accuracy: 0.3333
# Epoch 16/800
# 3/3 [==============================] - 0s 24ms/step - loss: 1.8896 - accuracy: 0.5131 - val_loss: 1.9007 - val_accuracy: 0.3333
# Epoch 17/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.8835 - accuracy: 0.4869 - val_loss: 1.8969 - val_accuracy: 0.3333
# Epoch 18/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.8798 - accuracy: 0.5438 - val_loss: 1.8925 - val_accuracy: 0.3333
# Epoch 19/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.8400 - accuracy: 0.5626 - val_loss: 1.8872 - val_accuracy: 0.3333
# Epoch 20/800
# 3/3 [==============================] - 0s 31ms/step - loss: 1.8216 - accuracy: 0.5888 - val_loss: 1.8809 - val_accuracy: 0.3333
# Epoch 21/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.8637 - accuracy: 0.5245 - val_loss: 1.8736 - val_accuracy: 0.3333
# Epoch 22/800
# 3/3 [==============================] - 0s 32ms/step - loss: 1.8110 - accuracy: 0.6270 - val_loss: 1.8667 - val_accuracy: 0.3333
# Epoch 23/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.8606 - accuracy: 0.5826 - val_loss: 1.8598 - val_accuracy: 0.3333
# Epoch 24/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.7809 - accuracy: 0.6546 - val_loss: 1.8539 - val_accuracy: 0.3333
# Epoch 25/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.8013 - accuracy: 0.5882 - val_loss: 1.8485 - val_accuracy: 0.3333
# Epoch 26/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.7997 - accuracy: 0.6208 - val_loss: 1.8435 - val_accuracy: 0.3333
# Epoch 27/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.7871 - accuracy: 0.6364 - val_loss: 1.8378 - val_accuracy: 0.3333
# Epoch 28/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.8018 - accuracy: 0.5839 - val_loss: 1.8293 - val_accuracy: 0.3333
# Epoch 29/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.7261 - accuracy: 0.6696 - val_loss: 1.8198 - val_accuracy: 0.3333
# Epoch 30/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.7153 - accuracy: 0.6958 - val_loss: 1.8082 - val_accuracy: 0.3333
# Epoch 31/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.7257 - accuracy: 0.6470 - val_loss: 1.7947 - val_accuracy: 0.3810
# Epoch 32/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.7118 - accuracy: 0.6433 - val_loss: 1.7816 - val_accuracy: 0.4286
# Epoch 33/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.7255 - accuracy: 0.6202 - val_loss: 1.7683 - val_accuracy: 0.4762
# Epoch 34/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.6732 - accuracy: 0.6621 - val_loss: 1.7549 - val_accuracy: 0.5714
# Epoch 35/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.7002 - accuracy: 0.6508 - val_loss: 1.7418 - val_accuracy: 0.5714
# Epoch 36/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.6580 - accuracy: 0.6514 - val_loss: 1.7294 - val_accuracy: 0.5714
# Epoch 37/800
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6516 - accuracy: 0.6815 - val_loss: 1.7166 - val_accuracy: 0.6190
# Epoch 38/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.6703 - accuracy: 0.6946 - val_loss: 1.7028 - val_accuracy: 0.6190
# Epoch 39/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.6097 - accuracy: 0.6996 - val_loss: 1.6871 - val_accuracy: 0.6190
# Epoch 40/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.6146 - accuracy: 0.7015 - val_loss: 1.6698 - val_accuracy: 0.6190
# Epoch 41/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.6163 - accuracy: 0.6727 - val_loss: 1.6527 - val_accuracy: 0.6190
# Epoch 42/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.5996 - accuracy: 0.7196 - val_loss: 1.6350 - val_accuracy: 0.6190
# Epoch 43/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.5803 - accuracy: 0.6815 - val_loss: 1.6163 - val_accuracy: 0.6190
# Epoch 44/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.5479 - accuracy: 0.6890 - val_loss: 1.5983 - val_accuracy: 0.6190
# Epoch 45/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.5216 - accuracy: 0.6877 - val_loss: 1.5812 - val_accuracy: 0.6190
# Epoch 46/800
# 3/3 [==============================] - 0s 24ms/step - loss: 1.4987 - accuracy: 0.7515 - val_loss: 1.5647 - val_accuracy: 0.6190
# Epoch 47/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.4997 - accuracy: 0.7240 - val_loss: 1.5474 - val_accuracy: 0.6190
# Epoch 48/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.5234 - accuracy: 0.6977 - val_loss: 1.5300 - val_accuracy: 0.6190
# Epoch 49/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.5027 - accuracy: 0.6827 - val_loss: 1.5122 - val_accuracy: 0.6190
# Epoch 50/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4301 - accuracy: 0.7228 - val_loss: 1.4949 - val_accuracy: 0.6190
# Epoch 51/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4413 - accuracy: 0.7346 - val_loss: 1.4773 - val_accuracy: 0.6190
# Epoch 52/800
# 3/3 [==============================] - 0s 34ms/step - loss: 1.4753 - accuracy: 0.7015 - val_loss: 1.4608 - val_accuracy: 0.6190
# Epoch 53/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.4257 - accuracy: 0.7140 - val_loss: 1.4459 - val_accuracy: 0.6190
# Epoch 54/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.4222 - accuracy: 0.6958 - val_loss: 1.4313 - val_accuracy: 0.6190
# Epoch 55/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.4324 - accuracy: 0.7372 - val_loss: 1.4189 - val_accuracy: 0.6190
# Epoch 56/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.3983 - accuracy: 0.6915 - val_loss: 1.4079 - val_accuracy: 0.6190
# Epoch 57/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3898 - accuracy: 0.7065 - val_loss: 1.3981 - val_accuracy: 0.6190
# Epoch 58/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.4165 - accuracy: 0.6583 - val_loss: 1.3884 - val_accuracy: 0.6667
# Epoch 59/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3088 - accuracy: 0.8016 - val_loss: 1.3791 - val_accuracy: 0.6667
# Epoch 60/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3442 - accuracy: 0.7634 - val_loss: 1.3709 - val_accuracy: 0.6667
# Epoch 61/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3540 - accuracy: 0.7021 - val_loss: 1.3621 - val_accuracy: 0.6667
# Epoch 62/800
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3619 - accuracy: 0.7265 - val_loss: 1.3533 - val_accuracy: 0.6667
# Epoch 63/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.3719 - accuracy: 0.7053 - val_loss: 1.3448 - val_accuracy: 0.6667
# Epoch 64/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3149 - accuracy: 0.7572 - val_loss: 1.3368 - val_accuracy: 0.6667
# Epoch 65/800
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3084 - accuracy: 0.7453 - val_loss: 1.3297 - val_accuracy: 0.6667
# Epoch 66/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2719 - accuracy: 0.7478 - val_loss: 1.3227 - val_accuracy: 0.6667
# Epoch 67/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.3094 - accuracy: 0.7403 - val_loss: 1.3162 - val_accuracy: 0.6667
# Epoch 68/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2903 - accuracy: 0.7440 - val_loss: 1.3107 - val_accuracy: 0.6667
# Epoch 69/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2776 - accuracy: 0.7647 - val_loss: 1.3049 - val_accuracy: 0.6667
# Epoch 70/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3260 - accuracy: 0.7265 - val_loss: 1.2987 - val_accuracy: 0.6667
# Epoch 71/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2890 - accuracy: 0.7459 - val_loss: 1.2924 - val_accuracy: 0.7143
# Epoch 72/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2355 - accuracy: 0.7766 - val_loss: 1.2872 - val_accuracy: 0.7143
# Epoch 73/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.2533 - accuracy: 0.7641 - val_loss: 1.2823 - val_accuracy: 0.6667
# Epoch 74/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.2298 - accuracy: 0.8235 - val_loss: 1.2791 - val_accuracy: 0.6667
# Epoch 75/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.2329 - accuracy: 0.8129 - val_loss: 1.2747 - val_accuracy: 0.6667
# Epoch 76/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.2472 - accuracy: 0.7497 - val_loss: 1.2710 - val_accuracy: 0.7143
# Epoch 77/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.2583 - accuracy: 0.7472 - val_loss: 1.2688 - val_accuracy: 0.7619
# Epoch 78/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2870 - accuracy: 0.8098 - val_loss: 1.2680 - val_accuracy: 0.7619
# Epoch 79/800
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2000 - accuracy: 0.7916 - val_loss: 1.2643 - val_accuracy: 0.7619
# Epoch 80/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2536 - accuracy: 0.7372 - val_loss: 1.2574 - val_accuracy: 0.8095
# Epoch 81/800
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2168 - accuracy: 0.7929 - val_loss: 1.2524 - val_accuracy: 0.8095
# Epoch 82/800
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2141 - accuracy: 0.7766 - val_loss: 1.2489 - val_accuracy: 0.8095
# Epoch 83/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2410 - accuracy: 0.7885 - val_loss: 1.2462 - val_accuracy: 0.8095
# Epoch 84/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2145 - accuracy: 0.7929 - val_loss: 1.2426 - val_accuracy: 0.8095
# Epoch 85/800
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1878 - accuracy: 0.7654 - val_loss: 1.2369 - val_accuracy: 0.8095
# Epoch 86/800
# 3/3 [==============================] - 0s 35ms/step - loss: 1.1854 - accuracy: 0.8279 - val_loss: 1.2304 - val_accuracy: 0.8095
# Epoch 87/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.2241 - accuracy: 0.7922 - val_loss: 1.2236 - val_accuracy: 0.8095
# Epoch 88/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1876 - accuracy: 0.7979 - val_loss: 1.2157 - val_accuracy: 0.8095
# Epoch 89/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2078 - accuracy: 0.8216 - val_loss: 1.2097 - val_accuracy: 0.8095
# Epoch 90/800
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1654 - accuracy: 0.7697 - val_loss: 1.2054 - val_accuracy: 0.8095
# Epoch 91/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1831 - accuracy: 0.7653 - val_loss: 1.2012 - val_accuracy: 0.8571
# Epoch 92/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1041 - accuracy: 0.8992 - val_loss: 1.1972 - val_accuracy: 0.8571
# Epoch 93/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1690 - accuracy: 0.8048 - val_loss: 1.1947 - val_accuracy: 0.8571
# Epoch 94/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1631 - accuracy: 0.8173 - val_loss: 1.1920 - val_accuracy: 0.8571
# Epoch 95/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1533 - accuracy: 0.8586 - val_loss: 1.1878 - val_accuracy: 0.8571
# Epoch 96/800
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1599 - accuracy: 0.8173 - val_loss: 1.1836 - val_accuracy: 0.8571
# Epoch 97/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1295 - accuracy: 0.8254 - val_loss: 1.1801 - val_accuracy: 0.8571
# Epoch 98/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1422 - accuracy: 0.8479 - val_loss: 1.1754 - val_accuracy: 0.8571
# Epoch 99/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1218 - accuracy: 0.8529 - val_loss: 1.1702 - val_accuracy: 0.8571
# Epoch 100/800
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1619 - accuracy: 0.8322 - val_loss: 1.1658 - val_accuracy: 0.8571
# Epoch 101/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1364 - accuracy: 0.8242 - val_loss: 1.1627 - val_accuracy: 0.9048
# Epoch 102/800
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1356 - accuracy: 0.8254 - val_loss: 1.1588 - val_accuracy: 0.9048
# Epoch 103/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.1253 - accuracy: 0.8661 - val_loss: 1.1535 - val_accuracy: 0.9048
# Epoch 104/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1227 - accuracy: 0.8579 - val_loss: 1.1442 - val_accuracy: 0.9048
# Epoch 105/800
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1356 - accuracy: 0.8217 - val_loss: 1.1377 - val_accuracy: 0.9048
# Epoch 106/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.1058 - accuracy: 0.8886 - val_loss: 1.1311 - val_accuracy: 0.9048
# Epoch 107/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1036 - accuracy: 0.8823 - val_loss: 1.1270 - val_accuracy: 0.9048
# Epoch 108/800
# 3/3 [==============================] - 0s 27ms/step - loss: 1.0965 - accuracy: 0.8492 - val_loss: 1.1234 - val_accuracy: 0.9048
# Epoch 109/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0703 - accuracy: 0.8786 - val_loss: 1.1199 - val_accuracy: 0.9048
# Epoch 110/800
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1330 - accuracy: 0.8154 - val_loss: 1.1150 - val_accuracy: 0.9524
# Epoch 111/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0961 - accuracy: 0.8686 - val_loss: 1.1101 - val_accuracy: 0.9524
# Epoch 112/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0647 - accuracy: 0.8992 - val_loss: 1.1079 - val_accuracy: 0.9524
# Epoch 113/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.0696 - accuracy: 0.9124 - val_loss: 1.1104 - val_accuracy: 0.9524
# Epoch 114/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1366 - accuracy: 0.8217 - val_loss: 1.1118 - val_accuracy: 0.9524
# Epoch 115/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0375 - accuracy: 0.8780 - val_loss: 1.1060 - val_accuracy: 0.9524
# Epoch 116/800
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0728 - accuracy: 0.8561 - val_loss: 1.0984 - val_accuracy: 0.9524
# Epoch 117/800
# 3/3 [==============================] - 0s 35ms/step - loss: 1.0273 - accuracy: 0.9174 - val_loss: 1.0874 - val_accuracy: 0.9524
# Epoch 118/800
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0606 - accuracy: 0.8880 - val_loss: 1.0843 - val_accuracy: 0.9524
# Epoch 119/800
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0099 - accuracy: 0.9080 - val_loss: 1.0815 - val_accuracy: 0.9524
# Epoch 120/800
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0428 - accuracy: 0.9274 - val_loss: 1.0770 - val_accuracy: 0.9524
# Epoch 121/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.0670 - accuracy: 0.8636 - val_loss: 1.0752 - val_accuracy: 0.9524
# Epoch 122/800
# 3/3 [==============================] - 0s 32ms/step - loss: 1.0044 - accuracy: 0.9130 - val_loss: 1.0718 - val_accuracy: 0.9524
# Epoch 123/800
# 3/3 [==============================] - 0s 32ms/step - loss: 1.0146 - accuracy: 0.9137 - val_loss: 1.0796 - val_accuracy: 0.9048
# Epoch 124/800
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0225 - accuracy: 0.8986 - val_loss: 1.0895 - val_accuracy: 0.8571
# Epoch 125/800
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0039 - accuracy: 0.9280 - val_loss: 1.0967 - val_accuracy: 0.8571
# Epoch 126/800
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0446 - accuracy: 0.8855 - val_loss: 1.1158 - val_accuracy: 0.8095
# Epoch 127/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.0524 - accuracy: 0.8630 - val_loss: 1.1278 - val_accuracy: 0.8095
# Epoch 128/800
# 3/3 [==============================] - 0s 26ms/step - loss: 0.9940 - accuracy: 0.9387 - val_loss: 1.1279 - val_accuracy: 0.8095
# Epoch 129/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.9709 - accuracy: 0.9355 - val_loss: 1.1162 - val_accuracy: 0.8095
# Epoch 130/800
# 3/3 [==============================] - 0s 32ms/step - loss: 1.0085 - accuracy: 0.9012 - val_loss: 1.1008 - val_accuracy: 0.8095
# Epoch 131/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9429 - accuracy: 0.9624 - val_loss: 1.0947 - val_accuracy: 0.8095
# Epoch 132/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9783 - accuracy: 0.9443 - val_loss: 1.0803 - val_accuracy: 0.8095
# Epoch 133/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9444 - accuracy: 0.9287 - val_loss: 1.0552 - val_accuracy: 0.8571
# Epoch 134/800
# 3/3 [==============================] - 0s 29ms/step - loss: 1.0212 - accuracy: 0.8761 - val_loss: 1.0329 - val_accuracy: 0.8571
# Epoch 135/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9455 - accuracy: 0.9474 - val_loss: 1.0125 - val_accuracy: 0.9048
# Epoch 136/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9993 - accuracy: 0.9036 - val_loss: 1.0319 - val_accuracy: 0.8571
# Epoch 137/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9735 - accuracy: 0.9043 - val_loss: 1.0615 - val_accuracy: 0.8095
# Epoch 138/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.9492 - accuracy: 0.9180 - val_loss: 1.0926 - val_accuracy: 0.8095
# Epoch 139/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.9289 - accuracy: 0.9262 - val_loss: 1.1136 - val_accuracy: 0.8095
# Epoch 140/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9059 - accuracy: 0.9549 - val_loss: 1.1109 - val_accuracy: 0.8095
# Epoch 141/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8784 - accuracy: 0.9787 - val_loss: 1.0849 - val_accuracy: 0.8095
# Epoch 142/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9138 - accuracy: 0.9368 - val_loss: 1.0711 - val_accuracy: 0.8095
# Epoch 143/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.9516 - accuracy: 0.9274 - val_loss: 1.0446 - val_accuracy: 0.8095
# Epoch 144/800
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9135 - accuracy: 0.9230 - val_loss: 0.9807 - val_accuracy: 0.9048
# Epoch 145/800
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0285 - accuracy: 0.9287 - val_loss: 0.9638 - val_accuracy: 0.9048
# Epoch 146/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8520 - accuracy: 0.9743 - val_loss: 0.9552 - val_accuracy: 0.9048
# Epoch 147/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.9135 - accuracy: 0.9212 - val_loss: 0.9362 - val_accuracy: 0.9048
# Epoch 148/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8982 - accuracy: 0.9137 - val_loss: 0.9291 - val_accuracy: 0.9524
# Epoch 149/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8925 - accuracy: 0.9700 - val_loss: 0.9322 - val_accuracy: 0.9048
# Epoch 150/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9251 - accuracy: 0.9393 - val_loss: 0.9501 - val_accuracy: 0.9048
# Epoch 151/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8514 - accuracy: 0.9593 - val_loss: 0.9620 - val_accuracy: 0.8571
# Epoch 152/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8677 - accuracy: 0.9606 - val_loss: 0.9464 - val_accuracy: 0.9048
# Epoch 153/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8800 - accuracy: 0.9255 - val_loss: 0.9440 - val_accuracy: 0.9048
# Epoch 154/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.9052 - accuracy: 0.9700 - val_loss: 0.9688 - val_accuracy: 0.8571
# Epoch 155/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.8595 - accuracy: 0.9650 - val_loss: 0.9633 - val_accuracy: 0.9048
# Epoch 156/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8631 - accuracy: 0.9337 - val_loss: 0.9648 - val_accuracy: 0.9048
# Epoch 157/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8564 - accuracy: 0.9537 - val_loss: 0.9363 - val_accuracy: 0.9048
# Epoch 158/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8083 - accuracy: 0.9881 - val_loss: 0.8975 - val_accuracy: 0.9524
# Epoch 159/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8319 - accuracy: 0.9700 - val_loss: 0.8781 - val_accuracy: 0.9524
# Epoch 160/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.8632 - accuracy: 0.9305 - val_loss: 0.8698 - val_accuracy: 0.9524
# Epoch 161/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.8347 - accuracy: 0.9606 - val_loss: 0.8839 - val_accuracy: 0.9524
# Epoch 162/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8220 - accuracy: 0.9656 - val_loss: 0.8902 - val_accuracy: 0.9524
# Epoch 163/800
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8377 - accuracy: 0.9531 - val_loss: 0.8833 - val_accuracy: 0.9524
# Epoch 164/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8646 - accuracy: 0.9362 - val_loss: 0.9077 - val_accuracy: 0.9048
# Epoch 165/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8434 - accuracy: 0.9650 - val_loss: 0.9033 - val_accuracy: 0.9048
# Epoch 166/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8530 - accuracy: 0.9512 - val_loss: 0.9237 - val_accuracy: 0.9048
# Epoch 167/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7927 - accuracy: 0.9850 - val_loss: 0.9079 - val_accuracy: 0.9048
# Epoch 168/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8845 - accuracy: 0.9287 - val_loss: 0.8720 - val_accuracy: 0.9524
# Epoch 169/800
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8142 - accuracy: 0.9549 - val_loss: 0.8684 - val_accuracy: 0.9524
# Epoch 170/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8045 - accuracy: 0.9518 - val_loss: 0.8932 - val_accuracy: 0.9048
# Epoch 171/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8333 - accuracy: 0.9806 - val_loss: 0.9271 - val_accuracy: 0.9048
# Epoch 172/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8833 - accuracy: 0.9393 - val_loss: 0.9517 - val_accuracy: 0.9048
# Epoch 173/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.8085 - accuracy: 0.9443 - val_loss: 0.9348 - val_accuracy: 0.9048
# Epoch 174/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.7860 - accuracy: 0.9806 - val_loss: 0.8803 - val_accuracy: 0.9524
# Epoch 175/800
# 3/3 [==============================] - 0s 26ms/step - loss: 0.8004 - accuracy: 0.9743 - val_loss: 0.8382 - val_accuracy: 0.9524
# Epoch 176/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7864 - accuracy: 0.9881 - val_loss: 0.8195 - val_accuracy: 0.9524
# Epoch 177/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7756 - accuracy: 0.9925 - val_loss: 0.8082 - val_accuracy: 0.9524
# Epoch 178/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7997 - accuracy: 0.9806 - val_loss: 0.8050 - val_accuracy: 0.9524
# Epoch 179/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7767 - accuracy: 0.9837 - val_loss: 0.7955 - val_accuracy: 0.9524
# Epoch 180/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8148 - accuracy: 0.9587 - val_loss: 0.7810 - val_accuracy: 1.0000
# Epoch 181/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8247 - accuracy: 0.9456 - val_loss: 0.7790 - val_accuracy: 1.0000
# Epoch 182/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7904 - accuracy: 0.9681 - val_loss: 0.7786 - val_accuracy: 1.0000
# Epoch 183/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8377 - accuracy: 0.9650 - val_loss: 0.7833 - val_accuracy: 1.0000
# Epoch 184/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7738 - accuracy: 0.9793 - val_loss: 0.7915 - val_accuracy: 0.9524
# Epoch 185/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.8233 - accuracy: 0.9674 - val_loss: 0.7999 - val_accuracy: 0.9524
# Epoch 186/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7904 - accuracy: 0.9743 - val_loss: 0.7898 - val_accuracy: 0.9524
# Epoch 187/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7747 - accuracy: 0.9956 - val_loss: 0.7867 - val_accuracy: 0.9524
# Epoch 188/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8085 - accuracy: 0.9793 - val_loss: 0.7916 - val_accuracy: 0.9524
# Epoch 189/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8058 - accuracy: 0.9499 - val_loss: 0.7952 - val_accuracy: 0.9524
# Epoch 190/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7465 - accuracy: 0.9762 - val_loss: 0.7914 - val_accuracy: 0.9524
# Epoch 191/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7842 - accuracy: 0.9743 - val_loss: 0.7831 - val_accuracy: 0.9524
# Epoch 192/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.8510 - accuracy: 0.9499 - val_loss: 0.7954 - val_accuracy: 0.9524
# Epoch 193/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7741 - accuracy: 0.9775 - val_loss: 0.8087 - val_accuracy: 0.9524
# Epoch 194/800
# 3/3 [==============================] - 0s 85ms/step - loss: 0.8079 - accuracy: 0.9668 - val_loss: 0.8172 - val_accuracy: 0.9524
# Epoch 195/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7850 - accuracy: 0.9499 - val_loss: 0.8293 - val_accuracy: 0.9524
# Epoch 196/800
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8444 - accuracy: 0.9531 - val_loss: 0.8215 - val_accuracy: 0.9524
# Epoch 197/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7679 - accuracy: 0.9743 - val_loss: 0.8419 - val_accuracy: 0.9524
# Epoch 198/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7538 - accuracy: 0.9868 - val_loss: 0.8387 - val_accuracy: 0.9524
# Epoch 199/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7834 - accuracy: 0.9606 - val_loss: 0.8098 - val_accuracy: 0.9524
# Epoch 200/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8352 - accuracy: 0.9637 - val_loss: 0.7814 - val_accuracy: 0.9524
# Epoch 201/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7720 - accuracy: 0.9837 - val_loss: 0.7743 - val_accuracy: 0.9524
# Epoch 202/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7405 - accuracy: 0.9837 - val_loss: 0.7711 - val_accuracy: 0.9524
# Epoch 203/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7954 - accuracy: 0.9562 - val_loss: 0.7642 - val_accuracy: 0.9524
# Epoch 204/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7893 - accuracy: 0.9725 - val_loss: 0.7570 - val_accuracy: 1.0000
# Epoch 205/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7316 - accuracy: 0.9837 - val_loss: 0.7553 - val_accuracy: 1.0000
# Epoch 206/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7771 - accuracy: 0.9743 - val_loss: 0.7649 - val_accuracy: 0.9524
# Epoch 207/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7749 - accuracy: 0.9787 - val_loss: 0.7781 - val_accuracy: 0.9524
# Epoch 208/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7987 - accuracy: 0.9650 - val_loss: 0.8185 - val_accuracy: 0.9524
# Epoch 209/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7581 - accuracy: 0.9743 - val_loss: 0.8361 - val_accuracy: 0.9524
# Epoch 210/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7421 - accuracy: 0.9637 - val_loss: 0.8196 - val_accuracy: 0.9524
# Epoch 211/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7652 - accuracy: 0.9731 - val_loss: 0.8033 - val_accuracy: 0.9524
# Epoch 212/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7671 - accuracy: 0.9668 - val_loss: 0.7904 - val_accuracy: 0.9524
# Epoch 213/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7256 - accuracy: 0.9743 - val_loss: 0.7661 - val_accuracy: 0.9524
# Epoch 214/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7876 - accuracy: 0.9650 - val_loss: 0.7434 - val_accuracy: 1.0000
# Epoch 215/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8216 - accuracy: 0.9512 - val_loss: 0.7321 - val_accuracy: 1.0000
# Epoch 216/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7491 - accuracy: 0.9775 - val_loss: 0.7284 - val_accuracy: 1.0000
# Epoch 217/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7241 - accuracy: 0.9868 - val_loss: 0.7267 - val_accuracy: 1.0000
# Epoch 218/800
# 3/3 [==============================] - 0s 86ms/step - loss: 0.7411 - accuracy: 0.9806 - val_loss: 0.7278 - val_accuracy: 1.0000
# Epoch 219/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7864 - accuracy: 0.9575 - val_loss: 0.7290 - val_accuracy: 1.0000
# Epoch 220/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7480 - accuracy: 0.9731 - val_loss: 0.7268 - val_accuracy: 1.0000
# Epoch 221/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7352 - accuracy: 0.9725 - val_loss: 0.7212 - val_accuracy: 1.0000
# Epoch 222/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7821 - accuracy: 0.9562 - val_loss: 0.7216 - val_accuracy: 1.0000
# Epoch 223/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8109 - accuracy: 0.9624 - val_loss: 0.7263 - val_accuracy: 1.0000
# Epoch 224/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7349 - accuracy: 0.9731 - val_loss: 0.7215 - val_accuracy: 1.0000
# Epoch 225/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7760 - accuracy: 0.9668 - val_loss: 0.7193 - val_accuracy: 1.0000
# Epoch 226/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7406 - accuracy: 0.9819 - val_loss: 0.7242 - val_accuracy: 1.0000
# Epoch 227/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7711 - accuracy: 0.9575 - val_loss: 0.7354 - val_accuracy: 1.0000
# Epoch 228/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7394 - accuracy: 0.9743 - val_loss: 0.7398 - val_accuracy: 0.9524
# Epoch 229/800
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7071 - accuracy: 0.9956 - val_loss: 0.7370 - val_accuracy: 0.9524
# Epoch 230/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7335 - accuracy: 0.9743 - val_loss: 0.7399 - val_accuracy: 0.9524
# Epoch 231/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7487 - accuracy: 0.9700 - val_loss: 0.7439 - val_accuracy: 0.9524
# Epoch 232/800
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7169 - accuracy: 0.9956 - val_loss: 0.7404 - val_accuracy: 0.9524
# Epoch 233/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7431 - accuracy: 0.9787 - val_loss: 0.7324 - val_accuracy: 0.9524
# Epoch 234/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7503 - accuracy: 0.9637 - val_loss: 0.7337 - val_accuracy: 0.9524
# Epoch 235/800
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7883 - accuracy: 0.9499 - val_loss: 0.7226 - val_accuracy: 1.0000
# Epoch 236/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.7389 - accuracy: 0.9650 - val_loss: 0.7189 - val_accuracy: 1.0000
# Epoch 237/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7214 - accuracy: 0.9881 - val_loss: 0.7150 - val_accuracy: 1.0000
# Epoch 238/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7322 - accuracy: 0.9775 - val_loss: 0.7074 - val_accuracy: 1.0000
# Epoch 239/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7527 - accuracy: 0.9650 - val_loss: 0.7056 - val_accuracy: 1.0000
# Epoch 240/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7929 - accuracy: 0.9593 - val_loss: 0.7047 - val_accuracy: 1.0000
# Epoch 241/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7429 - accuracy: 0.9656 - val_loss: 0.7065 - val_accuracy: 1.0000
# Epoch 242/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7395 - accuracy: 0.9743 - val_loss: 0.7174 - val_accuracy: 1.0000
# Epoch 243/800
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7397 - accuracy: 0.9650 - val_loss: 0.7479 - val_accuracy: 0.9524
# Epoch 244/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7475 - accuracy: 0.9668 - val_loss: 0.7626 - val_accuracy: 0.9524
# Epoch 245/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7195 - accuracy: 0.9712 - val_loss: 0.7524 - val_accuracy: 0.9524
# Epoch 246/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7218 - accuracy: 0.9637 - val_loss: 0.7447 - val_accuracy: 0.9524
# Epoch 247/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6925 - accuracy: 0.9925 - val_loss: 0.7142 - val_accuracy: 0.9524
# Epoch 248/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7616 - accuracy: 0.9743 - val_loss: 0.7030 - val_accuracy: 1.0000
# Epoch 249/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7547 - accuracy: 0.9668 - val_loss: 0.6962 - val_accuracy: 1.0000
# Epoch 250/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7409 - accuracy: 0.9668 - val_loss: 0.7025 - val_accuracy: 1.0000
# Epoch 251/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7197 - accuracy: 0.9837 - val_loss: 0.7188 - val_accuracy: 0.9524
# Epoch 252/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7287 - accuracy: 0.9837 - val_loss: 0.7183 - val_accuracy: 0.9524
# Epoch 253/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7780 - accuracy: 0.9437 - val_loss: 0.7080 - val_accuracy: 0.9524
# Epoch 254/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7227 - accuracy: 0.9743 - val_loss: 0.7034 - val_accuracy: 1.0000
# Epoch 255/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7233 - accuracy: 0.9787 - val_loss: 0.6958 - val_accuracy: 1.0000
# Epoch 256/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7725 - accuracy: 0.9543 - val_loss: 0.6906 - val_accuracy: 1.0000
# Epoch 257/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7247 - accuracy: 0.9731 - val_loss: 0.6910 - val_accuracy: 1.0000
# Epoch 258/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7051 - accuracy: 0.9700 - val_loss: 0.6897 - val_accuracy: 1.0000
# Epoch 259/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7019 - accuracy: 0.9787 - val_loss: 0.6905 - val_accuracy: 1.0000
# Epoch 260/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7187 - accuracy: 0.9881 - val_loss: 0.6893 - val_accuracy: 1.0000
# Epoch 261/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7181 - accuracy: 0.9637 - val_loss: 0.6888 - val_accuracy: 1.0000
# Epoch 262/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7319 - accuracy: 0.9731 - val_loss: 0.6901 - val_accuracy: 1.0000
# Epoch 263/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7061 - accuracy: 0.9775 - val_loss: 0.6929 - val_accuracy: 1.0000
# Epoch 264/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8006 - accuracy: 0.9237 - val_loss: 0.6891 - val_accuracy: 1.0000
# Epoch 265/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6917 - accuracy: 0.9956 - val_loss: 0.6886 - val_accuracy: 1.0000
# Epoch 266/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7306 - accuracy: 0.9862 - val_loss: 0.6893 - val_accuracy: 1.0000
# Epoch 267/800
# 3/3 [==============================] - 0s 85ms/step - loss: 0.7082 - accuracy: 0.9775 - val_loss: 0.6900 - val_accuracy: 1.0000
# Epoch 268/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7212 - accuracy: 0.9624 - val_loss: 0.6884 - val_accuracy: 1.0000
# Epoch 269/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7010 - accuracy: 0.9806 - val_loss: 0.6876 - val_accuracy: 1.0000
# Epoch 270/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7420 - accuracy: 0.9450 - val_loss: 0.6877 - val_accuracy: 1.0000
# Epoch 271/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7223 - accuracy: 0.9850 - val_loss: 0.6846 - val_accuracy: 1.0000
# Epoch 272/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6853 - accuracy: 0.9837 - val_loss: 0.6856 - val_accuracy: 1.0000
# Epoch 273/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7011 - accuracy: 0.9681 - val_loss: 0.6844 - val_accuracy: 1.0000
# Epoch 274/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6852 - accuracy: 0.9787 - val_loss: 0.6862 - val_accuracy: 1.0000
# Epoch 275/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7219 - accuracy: 0.9775 - val_loss: 0.6831 - val_accuracy: 1.0000
# Epoch 276/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7137 - accuracy: 0.9681 - val_loss: 0.6886 - val_accuracy: 1.0000
# Epoch 277/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6938 - accuracy: 0.9925 - val_loss: 0.7029 - val_accuracy: 0.9524
# Epoch 278/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7169 - accuracy: 0.9712 - val_loss: 0.7185 - val_accuracy: 0.9524
# Epoch 279/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6903 - accuracy: 0.9775 - val_loss: 0.7218 - val_accuracy: 0.9524
# Epoch 280/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7218 - accuracy: 0.9712 - val_loss: 0.6986 - val_accuracy: 0.9524
# Epoch 281/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6766 - accuracy: 0.9881 - val_loss: 0.6883 - val_accuracy: 1.0000
# Epoch 282/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6882 - accuracy: 0.9743 - val_loss: 0.6796 - val_accuracy: 1.0000
# Epoch 283/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6825 - accuracy: 0.9850 - val_loss: 0.6751 - val_accuracy: 1.0000
# Epoch 284/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6952 - accuracy: 0.9819 - val_loss: 0.6785 - val_accuracy: 1.0000
# Epoch 285/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6889 - accuracy: 0.9925 - val_loss: 0.6881 - val_accuracy: 1.0000
# Epoch 286/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7387 - accuracy: 0.9681 - val_loss: 0.6855 - val_accuracy: 1.0000
# Epoch 287/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6706 - accuracy: 0.9925 - val_loss: 0.6850 - val_accuracy: 1.0000
# Epoch 288/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7398 - accuracy: 0.9650 - val_loss: 0.6790 - val_accuracy: 1.0000
# Epoch 289/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6966 - accuracy: 0.9743 - val_loss: 0.6752 - val_accuracy: 1.0000
# Epoch 290/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6937 - accuracy: 0.9743 - val_loss: 0.6729 - val_accuracy: 1.0000
# Epoch 291/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6654 - accuracy: 0.9956 - val_loss: 0.6719 - val_accuracy: 1.0000
# Epoch 292/800
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7240 - accuracy: 0.9543 - val_loss: 0.6707 - val_accuracy: 1.0000
# Epoch 293/800
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7086 - accuracy: 0.9637 - val_loss: 0.6709 - val_accuracy: 1.0000
# Epoch 294/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7164 - accuracy: 0.9775 - val_loss: 0.6740 - val_accuracy: 1.0000
# Epoch 295/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7068 - accuracy: 0.9650 - val_loss: 0.6680 - val_accuracy: 1.0000
# Epoch 296/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7140 - accuracy: 0.9656 - val_loss: 0.6656 - val_accuracy: 1.0000
# Epoch 297/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7344 - accuracy: 0.9637 - val_loss: 0.6677 - val_accuracy: 1.0000
# Epoch 298/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6975 - accuracy: 0.9787 - val_loss: 0.6682 - val_accuracy: 1.0000
# Epoch 299/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7165 - accuracy: 0.9512 - val_loss: 0.6698 - val_accuracy: 1.0000
# Epoch 300/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6687 - accuracy: 0.9819 - val_loss: 0.6705 - val_accuracy: 1.0000
# Epoch 301/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7019 - accuracy: 0.9762 - val_loss: 0.6706 - val_accuracy: 1.0000
# Epoch 302/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6689 - accuracy: 0.9862 - val_loss: 0.6695 - val_accuracy: 1.0000
# Epoch 303/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7558 - accuracy: 0.9456 - val_loss: 0.6684 - val_accuracy: 1.0000
# Epoch 304/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6984 - accuracy: 0.9762 - val_loss: 0.6770 - val_accuracy: 1.0000
# Epoch 305/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7048 - accuracy: 0.9819 - val_loss: 0.6821 - val_accuracy: 0.9524
# Epoch 306/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7008 - accuracy: 0.9725 - val_loss: 0.6830 - val_accuracy: 0.9524
# Epoch 307/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6733 - accuracy: 0.9956 - val_loss: 0.6799 - val_accuracy: 0.9524
# Epoch 308/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6857 - accuracy: 0.9837 - val_loss: 0.6727 - val_accuracy: 1.0000
# Epoch 309/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7042 - accuracy: 0.9606 - val_loss: 0.6705 - val_accuracy: 1.0000
# Epoch 310/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6963 - accuracy: 0.9819 - val_loss: 0.6690 - val_accuracy: 1.0000
# Epoch 311/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7043 - accuracy: 0.9650 - val_loss: 0.6658 - val_accuracy: 1.0000
# Epoch 312/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6794 - accuracy: 0.9681 - val_loss: 0.6648 - val_accuracy: 1.0000
# Epoch 313/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6658 - accuracy: 0.9806 - val_loss: 0.6657 - val_accuracy: 1.0000
# Epoch 314/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6879 - accuracy: 0.9850 - val_loss: 0.6676 - val_accuracy: 1.0000
# Epoch 315/800
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6960 - accuracy: 0.9850 - val_loss: 0.6708 - val_accuracy: 1.0000
# Epoch 316/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6880 - accuracy: 0.9819 - val_loss: 0.6728 - val_accuracy: 1.0000
# Epoch 317/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6942 - accuracy: 0.9787 - val_loss: 0.6713 - val_accuracy: 1.0000
# Epoch 318/800
# 3/3 [==============================] - 0s 87ms/step - loss: 0.6706 - accuracy: 0.9681 - val_loss: 0.6735 - val_accuracy: 1.0000
# Epoch 319/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6778 - accuracy: 0.9712 - val_loss: 0.6724 - val_accuracy: 1.0000
# Epoch 320/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6817 - accuracy: 0.9787 - val_loss: 0.6687 - val_accuracy: 1.0000
# Epoch 321/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7478 - accuracy: 0.9725 - val_loss: 0.6631 - val_accuracy: 1.0000
# Epoch 322/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6761 - accuracy: 0.9862 - val_loss: 0.6622 - val_accuracy: 1.0000
# Epoch 323/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6750 - accuracy: 0.9881 - val_loss: 0.6613 - val_accuracy: 1.0000
# Epoch 324/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7316 - accuracy: 0.9587 - val_loss: 0.6615 - val_accuracy: 1.0000
# Epoch 325/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6931 - accuracy: 0.9862 - val_loss: 0.6697 - val_accuracy: 1.0000
# Epoch 326/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6670 - accuracy: 0.9806 - val_loss: 0.6759 - val_accuracy: 0.9524
# Epoch 327/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6644 - accuracy: 0.9819 - val_loss: 0.6915 - val_accuracy: 0.9524
# Epoch 328/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6536 - accuracy: 0.9775 - val_loss: 0.6962 - val_accuracy: 0.9524
# Epoch 329/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7208 - accuracy: 0.9606 - val_loss: 0.6688 - val_accuracy: 0.9524
# Epoch 330/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6732 - accuracy: 0.9862 - val_loss: 0.6573 - val_accuracy: 1.0000
# Epoch 331/800
# 3/3 [==============================] - 0s 26ms/step - loss: 0.7185 - accuracy: 0.9587 - val_loss: 0.6513 - val_accuracy: 1.0000
# Epoch 332/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6488 - accuracy: 0.9912 - val_loss: 0.6515 - val_accuracy: 1.0000
# Epoch 333/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6572 - accuracy: 0.9881 - val_loss: 0.6582 - val_accuracy: 1.0000
# Epoch 334/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6411 - accuracy: 0.9956 - val_loss: 0.6600 - val_accuracy: 1.0000
# Epoch 335/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6925 - accuracy: 0.9725 - val_loss: 0.6512 - val_accuracy: 1.0000
# Epoch 336/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6746 - accuracy: 0.9700 - val_loss: 0.6448 - val_accuracy: 1.0000
# Epoch 337/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7201 - accuracy: 0.9606 - val_loss: 0.6440 - val_accuracy: 1.0000
# Epoch 338/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6827 - accuracy: 0.9587 - val_loss: 0.6436 - val_accuracy: 1.0000
# Epoch 339/800
# ...
# Epoch 689/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.5336 - accuracy: 0.9925 - val_loss: 0.5473 - val_accuracy: 1.0000
# Epoch 690/800
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5433 - accuracy: 0.9806 - val_loss: 0.5490 - val_accuracy: 1.0000
# Epoch 691/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5576 - accuracy: 0.9587 - val_loss: 0.5495 - val_accuracy: 1.0000
# Epoch 692/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5199 - accuracy: 0.9925 - val_loss: 0.5477 - val_accuracy: 1.0000
# Epoch 693/800
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5551 - accuracy: 0.9650 - val_loss: 0.5451 - val_accuracy: 1.0000
# Epoch 694/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5197 - accuracy: 1.0000 - val_loss: 0.5448 - val_accuracy: 1.0000
# Epoch 695/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5766 - accuracy: 0.9700 - val_loss: 0.5430 - val_accuracy: 1.0000
# Epoch 696/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5224 - accuracy: 0.9956 - val_loss: 0.5394 - val_accuracy: 1.0000
# Epoch 697/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5259 - accuracy: 0.9787 - val_loss: 0.5354 - val_accuracy: 1.0000
# Epoch 698/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5260 - accuracy: 0.9956 - val_loss: 0.5346 - val_accuracy: 1.0000
# Epoch 699/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5332 - accuracy: 0.9850 - val_loss: 0.5367 - val_accuracy: 1.0000
# Epoch 700/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5382 - accuracy: 0.9837 - val_loss: 0.5383 - val_accuracy: 1.0000
# Epoch 701/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5618 - accuracy: 0.9787 - val_loss: 0.5286 - val_accuracy: 1.0000
# Epoch 702/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5845 - accuracy: 0.9606 - val_loss: 0.5589 - val_accuracy: 0.9524
# Epoch 703/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5141 - accuracy: 1.0000 - val_loss: 0.5829 - val_accuracy: 0.9524
# Epoch 704/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5542 - accuracy: 0.9775 - val_loss: 0.6006 - val_accuracy: 0.9524
# Epoch 705/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5588 - accuracy: 0.9606 - val_loss: 0.5929 - val_accuracy: 0.9524
# Epoch 706/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5775 - accuracy: 0.9787 - val_loss: 0.5628 - val_accuracy: 0.9524
# Epoch 707/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5613 - accuracy: 0.9743 - val_loss: 0.5442 - val_accuracy: 1.0000
# Epoch 708/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5325 - accuracy: 0.9850 - val_loss: 0.5394 - val_accuracy: 1.0000
# Epoch 709/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5179 - accuracy: 0.9862 - val_loss: 0.5486 - val_accuracy: 1.0000
# Epoch 710/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5339 - accuracy: 0.9912 - val_loss: 0.5568 - val_accuracy: 0.9524
# Epoch 711/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5368 - accuracy: 0.9881 - val_loss: 0.5710 - val_accuracy: 0.9524
# Epoch 712/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5536 - accuracy: 0.9725 - val_loss: 0.5654 - val_accuracy: 0.9524
# Epoch 713/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5438 - accuracy: 0.9725 - val_loss: 0.5574 - val_accuracy: 0.9524
# Epoch 714/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5412 - accuracy: 0.9775 - val_loss: 0.5494 - val_accuracy: 1.0000
# Epoch 715/800
# 3/3 [==============================] - 0s 85ms/step - loss: 0.5582 - accuracy: 0.9681 - val_loss: 0.5436 - val_accuracy: 1.0000
# Epoch 716/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5823 - accuracy: 0.9468 - val_loss: 0.5443 - val_accuracy: 1.0000
# Epoch 717/800
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5420 - accuracy: 0.9850 - val_loss: 0.5454 - val_accuracy: 1.0000
# Epoch 718/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5280 - accuracy: 0.9819 - val_loss: 0.5451 - val_accuracy: 1.0000
# Epoch 719/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5304 - accuracy: 0.9850 - val_loss: 0.5428 - val_accuracy: 1.0000
# Epoch 720/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5215 - accuracy: 0.9819 - val_loss: 0.5419 - val_accuracy: 1.0000
# Epoch 721/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5836 - accuracy: 0.9725 - val_loss: 0.5406 - val_accuracy: 1.0000
# Epoch 722/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5206 - accuracy: 0.9881 - val_loss: 0.5380 - val_accuracy: 1.0000
# Epoch 723/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5250 - accuracy: 0.9881 - val_loss: 0.5366 - val_accuracy: 1.0000
# Epoch 724/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.5456 - accuracy: 0.9819 - val_loss: 0.5341 - val_accuracy: 1.0000
# Epoch 725/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.5435 - accuracy: 0.9850 - val_loss: 0.5329 - val_accuracy: 1.0000
# Epoch 726/800
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5227 - accuracy: 0.9881 - val_loss: 0.5360 - val_accuracy: 1.0000
# Epoch 727/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5227 - accuracy: 0.9912 - val_loss: 0.5347 - val_accuracy: 1.0000
# Epoch 728/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5106 - accuracy: 0.9912 - val_loss: 0.5268 - val_accuracy: 1.0000
# Epoch 729/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5950 - accuracy: 0.9474 - val_loss: 0.5339 - val_accuracy: 1.0000
# Epoch 730/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5214 - accuracy: 0.9912 - val_loss: 0.5374 - val_accuracy: 1.0000
# Epoch 731/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5337 - accuracy: 0.9850 - val_loss: 0.5315 - val_accuracy: 1.0000
# Epoch 732/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6027 - accuracy: 0.9468 - val_loss: 0.5341 - val_accuracy: 1.0000
# Epoch 733/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5177 - accuracy: 0.9819 - val_loss: 0.5506 - val_accuracy: 0.9524
# Epoch 734/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5195 - accuracy: 0.9862 - val_loss: 0.5573 - val_accuracy: 0.9524
# Epoch 735/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5319 - accuracy: 0.9925 - val_loss: 0.5391 - val_accuracy: 1.0000
# Epoch 736/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5268 - accuracy: 0.9850 - val_loss: 0.5318 - val_accuracy: 1.0000
# Epoch 737/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5116 - accuracy: 0.9912 - val_loss: 0.5289 - val_accuracy: 1.0000
# Epoch 738/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5345 - accuracy: 0.9837 - val_loss: 0.5276 - val_accuracy: 1.0000
# Epoch 739/800
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5418 - accuracy: 0.9862 - val_loss: 0.5281 - val_accuracy: 1.0000
# Epoch 740/800
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5392 - accuracy: 0.9819 - val_loss: 0.5282 - val_accuracy: 1.0000
# Epoch 741/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5070 - accuracy: 0.9925 - val_loss: 0.5292 - val_accuracy: 1.0000
# Epoch 742/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5055 - accuracy: 0.9956 - val_loss: 0.5300 - val_accuracy: 1.0000
# Epoch 743/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5268 - accuracy: 0.9787 - val_loss: 0.5302 - val_accuracy: 1.0000
# Epoch 744/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5066 - accuracy: 1.0000 - val_loss: 0.5309 - val_accuracy: 1.0000
# Epoch 745/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5192 - accuracy: 0.9956 - val_loss: 0.5308 - val_accuracy: 1.0000
# Epoch 746/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5162 - accuracy: 0.9956 - val_loss: 0.5314 - val_accuracy: 1.0000
# Epoch 747/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5231 - accuracy: 0.9862 - val_loss: 0.5313 - val_accuracy: 1.0000
# Epoch 748/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5342 - accuracy: 0.9850 - val_loss: 0.5272 - val_accuracy: 1.0000
# Epoch 749/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5534 - accuracy: 0.9775 - val_loss: 0.5300 - val_accuracy: 1.0000
# Epoch 750/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5367 - accuracy: 0.9743 - val_loss: 0.5439 - val_accuracy: 0.9524
# Epoch 751/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5436 - accuracy: 0.9819 - val_loss: 0.5461 - val_accuracy: 0.9524
# Epoch 752/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5181 - accuracy: 0.9819 - val_loss: 0.5519 - val_accuracy: 0.9524
# Epoch 753/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5401 - accuracy: 0.9650 - val_loss: 0.5534 - val_accuracy: 0.9524
# Epoch 754/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5526 - accuracy: 0.9806 - val_loss: 0.5480 - val_accuracy: 0.9524
# Epoch 755/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5177 - accuracy: 0.9925 - val_loss: 0.5396 - val_accuracy: 0.9524
# Epoch 756/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5208 - accuracy: 0.9925 - val_loss: 0.5327 - val_accuracy: 1.0000
# Epoch 757/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5705 - accuracy: 0.9743 - val_loss: 0.5267 - val_accuracy: 1.0000
# Epoch 758/800
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5821 - accuracy: 0.9787 - val_loss: 0.5265 - val_accuracy: 1.0000
# Epoch 759/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5431 - accuracy: 0.9787 - val_loss: 0.5246 - val_accuracy: 1.0000
# Epoch 760/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5493 - accuracy: 0.9681 - val_loss: 0.5227 - val_accuracy: 1.0000
# Epoch 761/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5299 - accuracy: 0.9819 - val_loss: 0.5303 - val_accuracy: 1.0000
# Epoch 762/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5256 - accuracy: 0.9819 - val_loss: 0.5325 - val_accuracy: 1.0000
# Epoch 763/800
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5149 - accuracy: 0.9850 - val_loss: 0.5358 - val_accuracy: 1.0000
# Epoch 764/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5104 - accuracy: 0.9912 - val_loss: 0.5381 - val_accuracy: 1.0000
# Epoch 765/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5533 - accuracy: 0.9681 - val_loss: 0.5310 - val_accuracy: 1.0000
# Epoch 766/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5462 - accuracy: 0.9725 - val_loss: 0.5299 - val_accuracy: 1.0000
# Epoch 767/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5240 - accuracy: 0.9743 - val_loss: 0.5296 - val_accuracy: 1.0000
# Epoch 768/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5542 - accuracy: 0.9787 - val_loss: 0.5285 - val_accuracy: 1.0000
# Epoch 769/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5280 - accuracy: 0.9775 - val_loss: 0.5259 - val_accuracy: 1.0000
# Epoch 770/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5242 - accuracy: 0.9787 - val_loss: 0.5234 - val_accuracy: 1.0000
# Epoch 771/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5145 - accuracy: 0.9712 - val_loss: 0.5217 - val_accuracy: 1.0000
# Epoch 772/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5035 - accuracy: 0.9819 - val_loss: 0.5244 - val_accuracy: 1.0000
# Epoch 773/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5239 - accuracy: 0.9862 - val_loss: 0.5265 - val_accuracy: 1.0000
# Epoch 774/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.5247 - accuracy: 0.9862 - val_loss: 0.5303 - val_accuracy: 1.0000
# Epoch 775/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5193 - accuracy: 0.9881 - val_loss: 0.5296 - val_accuracy: 1.0000
# Epoch 776/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5060 - accuracy: 0.9956 - val_loss: 0.5327 - val_accuracy: 0.9524
# Epoch 777/800
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5355 - accuracy: 0.9650 - val_loss: 0.5352 - val_accuracy: 0.9524
# Epoch 778/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5035 - accuracy: 0.9956 - val_loss: 0.5372 - val_accuracy: 0.9524
# Epoch 779/800
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5069 - accuracy: 0.9868 - val_loss: 0.5378 - val_accuracy: 0.9524
# Epoch 780/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5084 - accuracy: 0.9819 - val_loss: 0.5361 - val_accuracy: 0.9524
# Epoch 781/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5179 - accuracy: 0.9819 - val_loss: 0.5291 - val_accuracy: 0.9524
# Epoch 782/800
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5132 - accuracy: 0.9837 - val_loss: 0.5231 - val_accuracy: 1.0000
# Epoch 783/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5129 - accuracy: 0.9819 - val_loss: 0.5233 - val_accuracy: 1.0000
# Epoch 784/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5232 - accuracy: 0.9650 - val_loss: 0.5241 - val_accuracy: 1.0000
# Epoch 785/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5345 - accuracy: 0.9787 - val_loss: 0.5364 - val_accuracy: 0.9524
# Epoch 786/800
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5185 - accuracy: 0.9850 - val_loss: 0.5432 - val_accuracy: 0.9524
# Epoch 787/800
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5151 - accuracy: 0.9681 - val_loss: 0.5465 - val_accuracy: 0.9524
# Epoch 788/800
# 3/3 [==============================] - 0s 82ms/step - loss: 0.5075 - accuracy: 0.9881 - val_loss: 0.5481 - val_accuracy: 0.9524
# Epoch 789/800
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5431 - accuracy: 0.9593 - val_loss: 0.5521 - val_accuracy: 0.9524
# Epoch 790/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5496 - accuracy: 0.9743 - val_loss: 0.5467 - val_accuracy: 0.9524
# Epoch 791/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5079 - accuracy: 0.9912 - val_loss: 0.5430 - val_accuracy: 0.9524
# Epoch 792/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5119 - accuracy: 0.9850 - val_loss: 0.5367 - val_accuracy: 0.9524
# Epoch 793/800
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5121 - accuracy: 0.9837 - val_loss: 0.5294 - val_accuracy: 0.9524
# Epoch 794/800
# 3/3 [==============================] - 0s 38ms/step - loss: 0.5452 - accuracy: 0.9862 - val_loss: 0.5215 - val_accuracy: 1.0000
# Epoch 795/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5044 - accuracy: 0.9787 - val_loss: 0.5284 - val_accuracy: 1.0000
# Epoch 796/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5355 - accuracy: 0.9787 - val_loss: 0.5325 - val_accuracy: 0.9524
# Epoch 797/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5259 - accuracy: 0.9787 - val_loss: 0.5301 - val_accuracy: 1.0000
# Epoch 798/800
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5130 - accuracy: 0.9925 - val_loss: 0.5248 - val_accuracy: 1.0000
# Epoch 799/800
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5797 - accuracy: 0.9712 - val_loss: 0.5214 - val_accuracy: 1.0000
# Epoch 800/800
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5007 - accuracy: 0.9819 - val_loss: 0.5222 - val_accuracy: 1.0000

# %% [markdown]
# #### Plot the learning curves
#
# Let's now plot the loss and accuracy for the training and validation sets.

# %%
#Run this cell to plot the new accuracy vs epoch graph

try:
    plt.plot(reg_history.history['accuracy'])
    plt.plot(reg_history.history['val_accuracy'])
except KeyError:
    plt.plot(reg_history.history['acc'])
    plt.plot(reg_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the new loss vs epoch graph

plt.plot(reg_history.history['loss'])
plt.plot(reg_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# We can see that the regularisation has helped to reduce the overfitting of the network.
# You will now incorporate callbacks into a new training run that implements early stopping and learning rate reduction on plateaux.
#
# Fill in the function below so that:
#
# * It creates an `EarlyStopping` callback object and a `ReduceLROnPlateau` callback object
# * The early stopping callback is used and monitors validation loss with the mode set to `"min"` and patience of 30.
# * The learning rate reduction on plateaux is used with a learning rate factor of 0.2 and a patience of 20.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_callbacks():
    """
    This function should create and return a tuple (early_stopping, learning_rate_reduction) callbacks.
    The callbacks should be instantiated according to the above requirements.
    """
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode='min', patience=30)
    learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=20)

    return early_stopping, learning_rate_reduction

# %% [markdown]
# Run the cell below to instantiate and train the regularised model with the callbacks.

# %%
call_model = get_regularised_model(train_data[0].shape, 0.3, 0.0001)
compile_model(call_model)
early_stopping, learning_rate_reduction = get_callbacks()
call_history = call_model.fit(train_data, train_targets, epochs=800, validation_split=0.15,
                         callbacks=[early_stopping, learning_rate_reduction], verbose=0)

# %%
learning_rate_reduction.patience
# Out:
# 20

# %% [markdown]
# Finally, let's replot the accuracy and loss graphs for our new model.

# %%
try:
    plt.plot(call_history.history['accuracy'])
    plt.plot(call_history.history['val_accuracy'])
except KeyError:
    plt.plot(call_history.history['acc'])
    plt.plot(call_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(call_history.history['loss'])
plt.plot(call_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Evaluate the model on the test set

test_loss, test_acc = call_model.evaluate(test_data, test_targets, verbose=0)
print("Test loss: {:.3f}\nTest accuracy: {:.2f}%".format(test_loss, 100 * test_acc))
# Out:
# Test loss: 0.159
# Test accuracy: 93.33%

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn how to save and load pre-trained models.
